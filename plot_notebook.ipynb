# %%
from plot import process_files_in_folder, create_histogram
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# Process files in the folder
# process_files_in_folder(folder_path)
def plotter(folder_path, n_trials):
    for density in range(n_trials):
    
        # Read the CSV file
        df = pd.read_csv(f"{folder_path}/{str(density)}_results.csv")
    
        # Extract columns for the first set of points
        flag = df.iloc[:,5]
        x1 = df.iloc[:, 4]  # 5th column
        y1 = df.iloc[:, 3]  # 4th column

        mask = (flag == 0)

        # Filter x1 and y1 based on the mask
        x1_filtered = x1[mask]
        y1_filtered = y1[mask]
    
        # Extract columns for the second set of points
        x2 = df.iloc[:, 7]  # 7th column
        y2 = df.iloc[:, 6]  # 6th column
    
        # Plot the first set of points
        plt.scatter(x1, y1, color='blue', label='POMDP')
    
        # Plot the second set of points
        plt.scatter(x2, y2, color='red', label='Policy Iteration')
    
        # Add labels and title
        plt.xlabel('X-axis')
        plt.ylabel('Y-axis')
        plt.title('Reward vs communication')
    
        # Add legend
        plt.legend()
    
        # Show the plot
        plt.grid(True)
        plt.show()


        # Extract columns for the first set of points
        y1 = df.iloc[:, 0]  # 4th column
    
        # Extract columns for the second set of points
        y2 = df.iloc[:, 8]  # 6th column
    
        # Plot the first set of points
        plt.plot(y1*1000, color='blue', label='POMDP')
    
        # Plot the second set of points
        plt.plot(y2, color='red', label='Policy Iteration')
    
        # Add labels and title
        plt.xlabel('X-axis')
        plt.ylabel('Y-axis')
        plt.title('Reward vs communication')
    
        # Add legend
        plt.legend()
    
        # Show the plot
        plt.grid(True)
        plt.show()

# %%
# Specify the folder containing the files
folder_path = '10state/estimation/csvs/'
number_of_trials = 5

plotter(folder_path, number_of_trials)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[25], line 5
#       2 folder_path = '10state/estimation/csvs/'
#       3 number_of_trials = 5
# ----> 5 plotter(folder_path, number_of_trials)
#
# Cell In[24], line 7, in plotter(folder_path, n_trials)
#       3 def plotter(folder_path, n_trials):
#       4     for density in range(n_trials):
#       5
#       6         # Read the CSV file
# ----> 7         df = pd.read_csv(f"{folder_path}/{str(density)}_results.csv")
#       9         # Extract columns for the first set of points
#      10         flag = df.iloc[:,5]
#
# File ~/EffCom/.venv/lib/python3.8/site-packages/pandas/io/parsers/readers.py:912, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     899 kwds_defaults = _refine_defaults_read(
#     900     dialect,
#     901     delimiter,
#    (...)
#     908     dtype_backend=dtype_backend,
#     909 )
#     910 kwds.update(kwds_defaults)
# --> 912 return _read(filepath_or_buffer, kwds)
#
# File ~/EffCom/.venv/lib/python3.8/site-packages/pandas/io/parsers/readers.py:577, in _read(filepath_or_buffer, kwds)
#     574 _validate_names(kwds.get("names", None))
#     576 # Create the parser.
# --> 577 parser = TextFileReader(filepath_or_buffer, **kwds)
#     579 if chunksize or iterator:
#     580     return parser
#
# File ~/EffCom/.venv/lib/python3.8/site-packages/pandas/io/parsers/readers.py:1407, in TextFileReader.__init__(self, f, engine, **kwds)
#    1404     self.options["has_index_names"] = kwds["has_index_names"]
#    1406 self.handles: IOHandles | None = None
# -> 1407 self._engine = self._make_engine(f, self.engine)
#
# File ~/EffCom/.venv/lib/python3.8/site-packages/pandas/io/parsers/readers.py:1661, in TextFileReader._make_engine(self, f, engine)
#    1659     if "b" not in mode:
#    1660         mode += "b"
# -> 1661 self.handles = get_handle(
#    1662     f,
#    1663     mode,
#    1664     encoding=self.options.get("encoding", None),
#    1665     compression=self.options.get("compression", None),
#    1666     memory_map=self.options.get("memory_map", False),
#    1667     is_text=is_text,
#    1668     errors=self.options.get("encoding_errors", "strict"),
#    1669     storage_options=self.options.get("storage_options", None),
#    1670 )
#    1671 assert self.handles is not None
#    1672 f = self.handles.handle
#
# File ~/EffCom/.venv/lib/python3.8/site-packages/pandas/io/common.py:859, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     854 elif isinstance(handle, str):
#     855     # Check whether the filename is to be opened in binary mode.
#     856     # Binary mode does not support 'encoding' and 'newline'.
#     857     if ioargs.encoding and "b" not in ioargs.mode:
#     858         # Encoding
# --> 859         handle = open(
#     860             handle,
#     861             ioargs.mode,
#     862             encoding=ioargs.encoding,
#     863             errors=errors,
#     864             newline="",
#     865         )
#     866     else:
#     867         # Binary mode
#     868         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: '10state/estimation/csvs//0_results.csv'

# %%
# Specify the folder containing the files
folder_path = '10_state_2_15/push_sparse_reward/'
number_of_trials = 5

plotter(folder_path, number_of_trials)

# %%
# Specify the folder containing the files
folder_path = '10_state_2_15/push_spread_reward/'
number_of_trials = 5

plotter(folder_path, number_of_trials)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[19], line 5
#       2 folder_path = '10_state_2_15/push_spread_reward/'
#       3 number_of_trials = 5
# ----> 5 plotter(folder_path, number_of_trials)
#
# Cell In[9], line 7, in plotter(folder_path, n_trials)
#       3 def plotter(folder_path, n_trials):
#       4     for density in range(n_trials):
#       5
#       6         # Read the CSV file
# ----> 7         df = pd.read_csv(f"{folder_path}/{str(density)}_results.csv")
#       9         # Extract columns for the first set of points
#      10         flag = df.iloc[:,5]
#
# File ~/EffCom/.venv/lib/python3.8/site-packages/pandas/io/parsers/readers.py:912, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     899 kwds_defaults = _refine_defaults_read(
#     900     dialect,
#     901     delimiter,
#    (...)
#     908     dtype_backend=dtype_backend,
#     909 )
#     910 kwds.update(kwds_defaults)
# --> 912 return _read(filepath_or_buffer, kwds)
#
# File ~/EffCom/.venv/lib/python3.8/site-packages/pandas/io/parsers/readers.py:577, in _read(filepath_or_buffer, kwds)
#     574 _validate_names(kwds.get("names", None))
#     576 # Create the parser.
# --> 577 parser = TextFileReader(filepath_or_buffer, **kwds)
#     579 if chunksize or iterator:
#     580     return parser
#
# File ~/EffCom/.venv/lib/python3.8/site-packages/pandas/io/parsers/readers.py:1407, in TextFileReader.__init__(self, f, engine, **kwds)
#    1404     self.options["has_index_names"] = kwds["has_index_names"]
#    1406 self.handles: IOHandles | None = None
# -> 1407 self._engine = self._make_engine(f, self.engine)
#
# File ~/EffCom/.venv/lib/python3.8/site-packages/pandas/io/parsers/readers.py:1661, in TextFileReader._make_engine(self, f, engine)
#    1659     if "b" not in mode:
#    1660         mode += "b"
# -> 1661 self.handles = get_handle(
#    1662     f,
#    1663     mode,
#    1664     encoding=self.options.get("encoding", None),
#    1665     compression=self.options.get("compression", None),
#    1666     memory_map=self.options.get("memory_map", False),
#    1667     is_text=is_text,
#    1668     errors=self.options.get("encoding_errors", "strict"),
#    1669     storage_options=self.options.get("storage_options", None),
#    1670 )
#    1671 assert self.handles is not None
#    1672 f = self.handles.handle
#
# File ~/EffCom/.venv/lib/python3.8/site-packages/pandas/io/common.py:859, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     854 elif isinstance(handle, str):
#     855     # Check whether the filename is to be opened in binary mode.
#     856     # Binary mode does not support 'encoding' and 'newline'.
#     857     if ioargs.encoding and "b" not in ioargs.mode:
#     858         # Encoding
# --> 859         handle = open(
#     860             handle,
#     861             ioargs.mode,
#     862             encoding=ioargs.encoding,
#     863             errors=errors,
#     864             newline="",
#     865         )
#     866     else:
#     867         # Binary mode
#     868         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: '10_state_2_15/push_spread_reward//1_results.csv'

# %%
# Out:
# ---------------------------------------------------------------------------
# NotADirectoryError                        Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 from main_all_in_one import __main__
#       2 import json
#       3 import os
#
# File ~/EffCom/main_all_in_one.py:7
#       5 import json
#       6 import os
# ----> 7 from julia import Pkg
#       8 from julia import NativeSARSOP, POMDPs
#       9 import concurrent.futures
#
# File <frozen importlib._bootstrap>:991, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:975, in _find_and_load_unlocked(name, import_)
#
# File <frozen importlib._bootstrap>:657, in _load_unlocked(spec)
#
# File <frozen importlib._bootstrap>:556, in module_from_spec(spec)
#
# File ~/EffCom/.venv/lib/python3.8/site-packages/julia/core.py:254, in JuliaModuleLoader.create_module(self, spec)
#     251 if juliapath == 'Main':
#     252     return sys.modules.setdefault(fullname,
#     253                                   JuliaMainModule(self, fullname))
# --> 254 elif self.julia.isafunction(juliapath):
#     255     return self.julia.eval(juliapath)
#     257 try:
#
# File ~/EffCom/.venv/lib/python3.8/site-packages/julia/core.py:242, in JuliaModuleLoader.julia(self)
#     240 @property
#     241 def julia(self):
# --> 242     self.__class__.julia = julia = Julia()
#     243     return julia
#
# File ~/EffCom/.venv/lib/python3.8/site-packages/julia/core.py:474, in Julia.__init__(self, init_julia, jl_init_path, runtime, jl_runtime_path, debug, **julia_options)
#     472     self.api = get_libjulia()
#     473 elif init_julia:
# --> 474     jlinfo = JuliaInfo.load(runtime)
#     475     if jlinfo.version_info < (0, 7):
#     476         raise RuntimeError("PyJulia does not support Julia < 0.7 anymore")
#
# File ~/EffCom/.venv/lib/python3.8/site-packages/julia/juliainfo.py:68, in JuliaInfo.load(cls, julia, **popen_kwargs)
#      61 """
#      62 Get basic information from `julia`.
#      63 """
#      65 juliainfo_script = os.path.join(
#      66     os.path.dirname(os.path.realpath(__file__)), "juliainfo.jl"
#      67 )
# ---> 68 proc = subprocess.Popen(
#      69     [julia, "--startup-file=no", juliainfo_script],
#      70     stdout=subprocess.PIPE,
#      71     stderr=subprocess.PIPE,
#      72     universal_newlines=True,
#      73     **popen_kwargs
#      74 )
#      76 stdout, stderr = proc.communicate()
#      77 retcode = proc.wait()
#
# File /usr/lib/python3.8/subprocess.py:858, in Popen.__init__(self, args, bufsize, executable, stdin, stdout, stderr, preexec_fn, close_fds, shell, cwd, env, universal_newlines, startupinfo, creationflags, restore_signals, start_new_session, pass_fds, encoding, errors, text)
#     854         if self.text_mode:
#     855             self.stderr = io.TextIOWrapper(self.stderr,
#     856                     encoding=encoding, errors=errors)
# --> 858     self._execute_child(args, executable, preexec_fn, close_fds,
#     859                         pass_fds, cwd, env,
#     860                         startupinfo, creationflags, shell,
#     861                         p2cread, p2cwrite,
#     862                         c2pread, c2pwrite,
#     863                         errread, errwrite,
#     864                         restore_signals, start_new_session)
#     865 except:
#     866     # Cleanup if the child failed starting.
#     867     for f in filter(None, (self.stdin, self.stdout, self.stderr)):
#
# File /usr/lib/python3.8/subprocess.py:1704, in Popen._execute_child(self, args, executable, preexec_fn, close_fds, pass_fds, cwd, env, startupinfo, creationflags, shell, p2cread, p2cwrite, c2pread, c2pwrite, errread, errwrite, restore_signals, start_new_session)
#    1702     if errno_num != 0:
#    1703         err_msg = os.strerror(errno_num)
# -> 1704     raise child_exception_type(errno_num, err_msg, err_filename)
#    1705 raise child_exception_type(err_msg)
#
# NotADirectoryError: [Errno 20] Not a directory: 'julia'
